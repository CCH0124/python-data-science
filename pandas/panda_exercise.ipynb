# %%
import pandas as pd

# %%
poke = pd.read_csv('pandas\\pokemon_data.csv')
print(poke.head(5))
# Out:
# #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ## Reading Data

# %%
print(poke.columns) ## Read Headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## Read each Column
poke['Name'][0:5]
poke['Attack']
poke[['Name', 'Attack']][0:5]
# Out:
#                     Name  Attack
# 0              Bulbasaur      49
# 1                Ivysaur      62
# 2               Venusaur      82
# 3  VenusaurMega Venusaur     100
# 4             Charmander      52

# %%
## Read each Row
poke.iloc[1]
poke.iloc[1:3]
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
poke.loc[poke['Type 1'] == 'Grass']
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur  Grass    Poison   45      49       49
# 1      2                  Ivysaur  Grass    Poison   60      62       63
# 2      3                 Venusaur  Grass    Poison   80      82       83
# 3      3    VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                   Oddish  Grass    Poison   45      50       55
# 49    44                    Gloom  Grass    Poison   60      65       70
# 50    45                Vileplume  Grass    Poison   75      80       85
# 75    69               Bellsprout  Grass    Poison   50      75       35
# 76    70               Weepinbell  Grass    Poison   65      90       50
# 77    71               Victreebel  Grass    Poison   80     105       65
# 110  102                Exeggcute  Grass   Psychic   60      40       80
# 111  103                Exeggutor  Grass   Psychic   95      95       85
# ...

# %%
## Read a specific Location 
poke.iloc[2, 1]
# Out:
# 'Venusaur'

# %% [markdown]
# ## Sorting and Describing Data

# %%
poke.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
poke.sort_values('Name', ascending=False)
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 794  718           Zygarde50% Forme    Dragon    Ground  108     100      121
# 695  634                   Zweilous      Dark    Dragon   72      85       70
# 46    41                      Zubat    Poison    Flying   40      45       35
# 631  570                      Zorua      Dark       NaN   40      65       40
# 632  571                    Zoroark      Dark       NaN   60     105       60
# 286  263                  Zigzagoon    Normal       NaN   38      30       41
# 707  644                     Zekrom    Dragon  Electric  100     150      120
# 582  523                  Zebstrika  Electric       NaN   75     100       63
# 157  145                     Zapdos  Electric    Flying   90      90       85
# 367  335                   Zangoose    Normal       NaN   73     115       60
# 793  717                    Yveltal      Dark    Flying  126     131       95
# ...

# %%
poke.sort_values(['Type 1', 'HP'], ascending=False)
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 351  321                Wailord  Water       NaN  170      90       45
# 655  594              Alomomola  Water       NaN  165      75       80
# 142  131                 Lapras  Water       Ice  130      85       80
# 145  134               Vaporeon  Water       NaN  130      65       60
# 350  320                Wailmer  Water       NaN  130      70       35
# 185  171                Lanturn  Water  Electric  125      58       58
# 470  423              Gastrodon  Water    Ground  111      83       68
# 372  340               Whiscash  Water    Ground  110      78       73
# 597  537             Seismitoad  Water    Ground  105      95       75
# 199  184              Azumarill  Water     Fairy  100      50       80
# 264  245                Suicune  Water       NaN  100      75      115
# 282  260               Swampert  Water    Ground  100     110       90
# ...

# %% [markdown]
# ## Making changes to the data

# %%
# add column
# poke['Total'] = poke['Attack'] + poke['Defense']
# poke.head(1)
# or
poke['Total'] = poke.iloc[:, 4:6].sum(axis=1)

# %%
# drop column
poke = poke.drop(columns=['Total'])
poke.head(1)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %% [markdown]
# ## Saving Data

# %%
poke.to_csv('pandas\\modified.csv', index=False)

# %% [markdown]
# ## Filtering Data

# %%
new_data = poke.loc[(poke['Type 1'] == 'Grass') & (poke['Type 2'] == 'Poison')]
print(new_data.reset_index)
# Out:
# <bound method DataFrame.reset_index of        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# ...

# %%
poke.loc[poke['Name'].str.contains('Mega')]
#poke.loc[~poke['Name'].str.contains('Mega')] # delete data
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %% [markdown]
# ## Conditional Change

# %%
poke.loc[poke['Total'] > 100, ['Generation', 'Legendary']] = 'VALUE'

# %% [markdown]
# ## Aggregate Statistics(Groupby)

# %%
poke.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
poke.groupby(['Type 1']).sum()
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# Type 1
# Bug       23080  3925    4897     4880     3717     4471   4256   8822
# Dark      14302  2071    2740     2177     2314     2155   2361   4811
# Dragon    15180  2666    3588     2764     3099     2843   2657   6254
# Electric  15994  2631    3040     2917     3961     3243   3718   5671
# Fairy      7642  1260    1046     1117     1335     1440    826   2306
# Fighting   9824  1886    2613     1780     1434     1747   1784   4499
# Fire      17025  3635    4408     3524     4627     3755   3871   8043
# Flying     2711   283     315      265      377      290    410    598
# Ghost     15568  2062    2361     2598     2539     2447   2059   4423
# Grass     24141  4709    5125     4956     5425     4930   4335   9834
# Ground    11401  2361    3064     2715     1807     2008   2045   5425
# Ice       10165  1728    1746     1714     1861     1831   1523   3474
# ...
